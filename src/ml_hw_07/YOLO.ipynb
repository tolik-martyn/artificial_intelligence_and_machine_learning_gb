# %% [markdown]
# # 1. Detection

# %%
from ultralytics import YOLO

# %%
# Загрузка предобученной модели YOLOv8n
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 294MB/s]

# %%
# Обучение модели на наборе данных COCO128 в течение 10 эпох
model.train(data='coco128.yaml', epochs=10, batch=16, lrf=00.1, lr0=0.001)
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# ...

# %%
# Предсказание по изображению
model('https://ultralytics.com/images/bus.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 159.8ms
# Speed: 2.3ms preprocess, 159.8ms inference, 9.3ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes', 'masks']
#  masks: ultralytics.yolo.engine.results.Masks object
# ...

# %% [markdown]
# ### Изменения в коде для повышения его точности:
# 1. `Увеличение числа эпох (epochs) до 10`: Увеличение числа эпох позволяет модели обучаться дольше и иметь больше шансов улучшить свою точность. Дополнительные эпохи обучения могут помочь модели лучше адаптироваться к данным и выучить более сложные паттерны, что в свою очередь может улучшить точность предсказаний.
# 2. `Уменьшение размера пакета (batch_size) до 16`: Уменьшение размера пакета позволяет модели видеть более разнообразные примеры во время обучения. Это может помочь модели лучше обобщать и выявлять общие закономерности в данных. Меньший размер пакета также может помочь избежать затухания градиентов и улучшить сходимость модели.
# 3. `Изменение скорости обучения (learning rate) до 0.001`: Скорость обучения контролирует, насколько сильно обновляются веса модели на каждом шаге обучения. Увеличение скорости обучения может помочь модели быстрее сойтись к оптимальным весам. Однако слишком высокая скорость обучения может привести к расходимости модели. Установка скорости обучения равной 0.001 является компромиссом, который может помочь модели эффективно настраивать веса и достигать более высокой точности.

# %% [markdown]
# # 2. Segmentation

# %%
# Создание экземпляра модели
model = YOLO('yolov8n-seg.pt')
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 222MB/s]

# %%
# Загрузка и обучение модели на тренировочных данных
model.train(data='coco128-seg.yaml', epochs=10)
# Out:
# Ultralytics YOLOv8.0.134 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# ...

# %%
# Предсказание по изображению
model('https://ultralytics.com/images/bus.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 167.1ms
# Speed: 3.2ms preprocess, 167.1ms inference, 9.8ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes', 'masks']
#  masks: ultralytics.yolo.engine.results.Masks object
# ...

# %% [markdown]
# ### Изменения в коде для повышения его точности:
# 1. `Увеличение числа эпох (epochs) до 10`: Увеличение числа эпох позволяет модели обучаться дольше и иметь больше шансов улучшить свою точность. Дополнительные эпохи обучения могут помочь модели лучше адаптироваться к данным и выучить более сложные паттерны, что в свою очередь может улучшить точность предсказаний.
